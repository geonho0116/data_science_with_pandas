# %%
# 라이브러리 로드
# 분석에 사용할 pandas, 수치계산에 사용할 numpy, 시각화에 사용할 seaborn을 불러온다.
# 구 버전의 주피터 노트북에서는 %matplotlib inline 설정을 해줘야 그래프를 시각화 할 수 있다.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
if os.name == 'nt': # 윈도우 운영체제일 때
    plt.rc("font", family = "Malgun Gothic")
else: # Mac 운영체제일 때
    plt.rc("font", family="AppleGothic")

# 마이너스 폰트 깨지는 문제에 대한 대처
plt.rc("axes", unicode_minus=False)

# %%
# 레티나 설정을 해주면 글씨가 좀 더 선명하게 보인다.
# 폰트 주변이 흐릿하게 보이는 것을 방지한다.
# %config InlineBackend.figure_format='retina'

# %%
df = pd.read_csv("data/건강검진정보(2017).csv", encoding="cp949")
df.shape
# Out:
# (1000000, 34)

# %%
df.head()
# Out:
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  \
# 0  2017        1     1            8    43        170         75  90.0    1.0
# 1  2017        2     1            7    11        180         80  89.0    0.9
# 2  2017        3     1            9    41        165         75  91.0    1.2
# 3  2017        4     1           11    48        175         80  91.0    1.5
# 4  2017        5     1           11    30        165         60  80.0    1.0
#
#    시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 0    1.0  ...   40.0   1.0   1.0         1      NaN    NaN      NaN
# 1    1.2  ...   27.0   3.0   0.0         1      NaN    NaN      NaN
# 2    1.5  ...   68.0   1.0   0.0         0      NaN    NaN      NaN
# 3    1.2  ...   18.0   1.0   0.0         1      NaN    NaN      NaN
# 4    1.2  ...   25.0   1.0   0.0         1      NaN    NaN      NaN
#
#    제3대구치(사랑니)이상   치석   데이터공개일자
# 0           NaN  1.0  20181126
# ...

# %%
df.sample()
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 298360  2017   298361     2           15    26        155         60  89.0
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진수검여부  치아우식증유무  결손치유무  \
# 298360    0.5    0.8  ...   20.0   1.0   0.0         0      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상  치석   데이터공개일자
# 298360      NaN           NaN NaN  20181126
#
# [1 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   기준년도          1000000 non-null  int64
#  1   가입자일련번호       1000000 non-null  int64
#  2   성별코드          1000000 non-null  int64
#  3   연령대코드(5세단위)   1000000 non-null  int64
#  4   시도코드          1000000 non-null  int64
#  5   신장(5Cm단위)     1000000 non-null  int64
#  6   체중(5Kg단위)     1000000 non-null  int64
#  7   허리둘레          999734 non-null   float64
#  8   시력(좌)         999817 non-null   float64
#  9   시력(우)         999811 non-null   float64
#  10  청력(좌)         999842 non-null   float64
#  11  청력(우)         999844 non-null   float64
#  12  수축기혈압         999981 non-null   float64
#  13  이완기혈압         999982 non-null   float64
#  14  식전혈당(공복혈당)    999958 non-null   float64
#  15  총콜레스테롤        999957 non-null   float64
#  16  트리글리세라이드      999955 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상', '치석',
#        '데이터공개일자'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 기준년도              int64
# 가입자일련번호           int64
# 성별코드              int64
# 연령대코드(5세단위)       int64
# 시도코드              int64
# 신장(5Cm단위)         int64
# 체중(5Kg단위)         int64
# 허리둘레            float64
# 시력(좌)           float64
# 시력(우)           float64
# 청력(좌)           float64
# 청력(우)           float64
# 수축기혈압           float64
# 이완기혈압           float64
# 식전혈당(공복혈당)      float64
# 총콜레스테롤          float64
# 트리글리세라이드        float64
# HDL콜레스테롤        float64
# LDL콜레스테롤        float64
# 혈색소             float64
# 요단백             float64
# 혈청크레아티닌         float64
# (혈청지오티)AST      float64
# (혈청지오티)ALT      float64
# 감마지티피           float64
# 흡연상태            float64
# 음주여부            float64
# 구강검진수검여부          int64
# 치아우식증유무         float64
# 결손치유무           float64
# 치아마모증유무         float64
# 제3대구치(사랑니)이상    float64
# 치석              float64
# 데이터공개일자           int64
# dtype: object

# %%
#isnull을통해 결측치를 bool값으로 표시하고 sum을 하면 컬러마다 결측치 수를 세어준다.
df.isnull().sum() #df.isna()
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)             0
# 체중(5Kg단위)             0
# 허리둘레                266
# 시력(좌)               183
# 시력(우)               189
# 청력(좌)               158
# 청력(우)               156
# 수축기혈압                19
# 이완기혈압                18
# 식전혈당(공복혈당)           42
# 총콜레스테롤               43
# 트리글리세라이드             45
# HDL콜레스테롤             44
# LDL콜레스테롤           2912
# 혈색소                  52
# 요단백                4592
# 혈청크레아티닌              43
# (혈청지오티)AST           41
# (혈청지오티)ALT           42
# 감마지티피                42
# 흡연상태                144
# 음주여부                536
# 구강검진수검여부              0
# 치아우식증유무         1000000
# 결손치유무           1000000
# 치아마모증유무         1000000
# 제3대구치(사랑니)이상    1000000
# 치석               599477
# 데이터공개일자               0
# dtype: int64

# %%
# 판다스에 내장된 plot을 통해 시각화한다.
df.isnull().sum().plot.barh(figsize=(10,9))

# %%
df[["(혈청지오티)ALT","(혈청지오티)AST"]].head()
# Out:
#    (혈청지오티)ALT  (혈청지오티)AST
# 0        35.0        21.0
# 1        36.0        20.0
# 2        32.0        47.0
# 3        34.0        29.0
# 4        12.0        19.0

# %%
df[["(혈청지오티)ALT","(혈청지오티)AST"]].describe()
# Out:
#           (혈청지오티)ALT     (혈청지오티)AST
# count  999958.000000  999959.000000
# mean       25.749509      25.994671
# std        26.294770      23.587469
# min         1.000000       1.000000
# 25%        15.000000      19.000000
# 50%        20.000000      23.000000
# 75%        29.000000      28.000000
# max      7210.000000    9999.000000

# %%
df["성별코드"].value_counts()
# Out:
# 1    530410
# 2    469590
# Name: 성별코드, dtype: int64

# %%
df["흡연상태"].value_counts()
# Out:
# 1.0    607942
# 3.0    215702
# 2.0    176212
# Name: 흡연상태, dtype: int64

# %%
df.groupby(["성별코드"])["가입자일련번호"].count()
# Out:
# 성별코드
# 1    530410
# 2    469590
# Name: 가입자일련번호, dtype: int64

# %%
df.groupby(["성별코드", "음주여부"])["가입자일련번호"].count()
# Out:
# 성별코드  음주여부
# 1     0.0     173612
#       1.0     356587
# 2     0.0     326827
#       1.0     142438
# Name: 가입자일련번호, dtype: int64

# %%
df.groupby(["성별코드", "음주여부"])["감마지티피"].mean()
# Out:
# 성별코드  음주여부
# 1     0.0     34.739868
#       1.0     56.610981
# 2     0.0     22.612408
#       1.0     25.001018
# Name: 감마지티피, dtype: float64

# %%
df.groupby(["성별코드", "음주여부"])["감마지티피"].describe()
# Out:
#               count       mean        std  min   25%   50%   75%    max
# 성별코드 음주여부
# 1    0.0   173604.0  34.739868  37.606197  1.0  18.0  25.0  38.0  999.0
#      1.0   356576.0  56.610981  68.851128  1.0  24.0  37.0  63.0  999.0
# 2    0.0   326813.0  22.612408  25.203579  1.0  13.0  17.0  24.0  999.0
#      1.0   142429.0  25.001018  36.725100  1.0  13.0  17.0  25.0  999.0

# %%
df.groupby(["성별코드","음주여부"])["감마지티피"].agg(
    ["count","mean","median"])
# Out:
#             count       mean  median
# 성별코드 음주여부
# 1    0.0   173604  34.739868    25.0
#      1.0   356576  56.610981    37.0
# 2    0.0   326813  22.612408    17.0
#      1.0   142429  25.001018    17.0

# %%
df.pivot_table(index="음주여부", values="가입자일련번호", aggfunc="count").T
# Out:
# 음주여부        0.0     1.0
# 가입자일련번호  500439  499025

# %%
pd.pivot_table(df, index="음주여부", values="감마지티피", aggfunc=["mean","median"])
#기본값 mean
# Out:
#            mean median
#           감마지티피  감마지티피
# 음주여부
# 0.0   26.819650   19.0
# 1.0   47.588675   30.0

# %%
pd.pivot_table(df, index=["음주여부","성별코드"], values="감마지티피", aggfunc="describe")
# Out:
#             25%   50%   75%     count    max       mean  min        std
# 음주여부 성별코드
# 0.0  1     18.0  25.0  38.0  173604.0  999.0  34.739868  1.0  37.606197
#      2     13.0  17.0  24.0  326813.0  999.0  22.612408  1.0  25.203579
# 1.0  1     24.0  37.0  63.0  356576.0  999.0  56.610981  1.0  68.851128
#      2     13.0  17.0  25.0  142429.0  999.0  25.001018  1.0  36.725100

# %%
#히스토그램(막대그래프)

# %%
h = df.iloc[:,:12].hist(figsize=(12,12))

# %%
h = df.iloc[:,12:24].hist(figsize=(12,12),bins=100)

# %%
h = df.iloc[:,24:].hist(figsize=(12,12),bins=100)

# %%
# 샘플데이터 추출하기
# seaborn 의 그래프는 내부에서 수학적 연산이 되기 때문에 데이터가 많으면 속도가 느리다.-> 일부만 샘플링하여 사용한다.

# %%
df_sample = df.sample(1000,random_state=1) # random_state를 지정하면 항상 같은 샘플만 제공
df_sample.shape
# Out:
# (1000, 34)

# %%
sns.set(font_scale=1, font="Malgun Gothic")
sns.countplot(x="음주여부", data=df, hue="성별코드")

# %%
sns.countplot(data=df, x="연령대코드(5세단위)", hue="음주여부")

# %%
df
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 0       2017        1     1            8    43        170         75  90.0
# 1       2017        2     1            7    11        180         80  89.0
# 2       2017        3     1            9    41        165         75  91.0
# 3       2017        4     1           11    48        175         80  91.0
# 4       2017        5     1           11    30        165         60  80.0
# ...      ...      ...   ...          ...   ...        ...        ...   ...
# 999995  2017   999996     1           10    48        175         80  92.1
# 999996  2017   999997     1            8    41        170         75  86.0
# 999997  2017   999998     2            9    26        155         50  68.0
# 999998  2017   999999     1            6    29        175         60  72.0
# 999999  2017  1000000     1           11    41        160         70  90.5
#
# ...

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=df, x="신장(5Cm단위)")

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=df, x="체중(5Kg단위)")

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=df, x="신장(5Cm단위)",hue="연령대코드(5세단위)")

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=df, x="체중(5Kg단위)", hue="음주여부")
